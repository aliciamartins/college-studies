# %% [markdown]
# Olaaaaaaaaa, este e' um exemplo de notebook compartilhado

# %% [markdown]
# A seguir o material de aula e vamos testar algumas operaçoes em Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
2*5 + 3*15 * 75-18 / 15+4
# Out:
# 3387.8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A teoria de tudo;
# Estrelas além do tempo;
# Blade runner

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# anotacao ....

# %%
x= np.linspace(0,5,100)
y= np.sin(4*x)*np.exp(-x)
z= np.exp(-x)*np.cos(4*x)
plt.figure(dpi=100, facecolor='m')
plt.plot(x,y,'m-.', label='$e^{-x}sin(4x)$', linewidth= 1.0)
plt.legend()

# %%
x= np.linspace(0,10,90)
y= np.sin(7*x)*np.exp(-x)
z= np.exp(-x)*np.cos(4*x)
plt.figure(dpi=100, facecolor='c')
plt.plot(x,y,'m-.',label='$e^{-x}sin(4x)$',linewidth= 2.0)
plt.legend()

# %%
plt.plot(x,y,label='$e^{-x}cos(4x)$',linewidth=4.0)
plt.xlabel('eixo x')
plt.ylabel('value eixo y')
plt.legend()

# %%
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
print(x)
# Out:
# [ 0.          0.11235955  0.2247191   0.33707865  0.4494382   0.56179775
#   0.6741573   0.78651685  0.8988764   1.01123596  1.12359551  1.23595506
#   1.34831461  1.46067416  1.57303371  1.68539326  1.79775281  1.91011236
#   2.02247191  2.13483146  2.24719101  2.35955056  2.47191011  2.58426966
#   2.69662921  2.80898876  2.92134831  3.03370787  3.14606742  3.25842697
#   3.37078652  3.48314607  3.59550562  3.70786517  3.82022472  3.93258427
#   4.04494382  4.15730337  4.26966292  4.38202247  4.49438202  4.60674157
#   4.71910112  4.83146067  4.94382022  5.05617978  5.16853933  5.28089888
#   5.39325843  5.50561798  5.61797753  5.73033708  5.84269663  5.95505618
#   6.06741573  6.17977528  6.29213483  6.40449438  6.51685393  6.62921348
#   6.74157303  6.85393258  6.96629213  7.07865169  7.19101124  7.30337079
#   7.41573034  7.52808989  7.64044944  7.75280899  7.86516854  7.97752809
#   8.08988764  8.20224719  8.31460674  8.42696629  8.53932584  8.65168539
# ...

# %% [markdown]
# Ciao Mondo
# nao e´ tchau!!!

# %% [markdown]
# **Faz negrito** *Faz itálico* Isso é $LaTeX$, $f*(x)= e^(1/x)$

# %% [markdown]
# Meu nome é **Flávia Nascimento**, nasci em São Paulo, vou fazer _20 anos_ este mês e pretendo me especializar em ~~engenharia biomédica~~.

# %% [markdown]
# Meu nome é **Igor Coutinho**, nasci em *São Paulo*, tenho 19 anos e minha cor preferida é *vermelho*. Ainda não tenho certeza do que irei cursar.

# %% [markdown]
# Meu nome é **Gustavo Watari**, nasci na cidade de *Suzano* em $2002$, tenho $18$ anos, minha cor preferida é vermelho, meu curso pós bi é engenharia de Energia

# %% [markdown]
# Meu nome é **Gustavo Rocha** e nasci na cidade de *São Paulo* no ano de **2002.** Minha $cor$ *favorita* é **azul**, pretendo $cursar$ **Química** e meu $prato$ *predileto* é **lasanha.**

# %% [markdown]
# Meu nome é Andrew Rodrigues, nasci e vivi em Sorocaba, onde ainda resido, tenho 18 anos e minha cor favorita é verde, apesar de eu ter uma quedinha por tons neutros, em geral. Após o BCT pretendo

# %% [markdown]
# Meu nome é **Gustavo Alves**, nasci em **Guarulhos** e ainda moro aqui. Tenho 18 anos e não tenho uma cor preferida. Quero cursar Biologia. Gosto de comer panquecas de carne. *meu hobbie é ler*

# %% [markdown]
# Olá, meu nome é **Bruno**, nasci em *Santos* e resido em *Cubatão, Litoral de São Paulo*. Minha cor favorita é *Roxo* e eu pretendo me especializar em $NEUROCIENCIA$.

# %% [markdown]
# Meu nome é **Pedro Bernardino**, nasci em *Piracicaba* mas morei sempre em $Saltinho$. Minha cor preferida é **preto** e eu pretendo cursar *biotecnologia*.

# %% [markdown]
# Meu nome é **Adriano Annoni** tenho 18 anos e pretendo fazer $gestão$

# %% [markdown]
# Eu me chamo *Carlos Henrique*, nasci em São Bernanrdo do Campo, minha cor preferida é verde. Pretendo cursar **ciência da computação**

# %% [markdown]
# Meu nome é **Pedro Santos**, nasci e moro em São Paulo. Tenho 19 anos e minha cor preferida é *preto*. Após o *BCT* pretendo cursar **Engenharia de Gestão**.

# %% [markdown]
# Meu **nome** é *Gabriel* Zonatto, nasci em **1996** na cidade *de* Santo André, minha cor preferida é o laranja (**segunto estatística das quais eu não me recordo da *fonte*, essa é a cor preferida de apenas $0.05$ da população masculina**)

# %% [markdown]
# Olá, meu nome é **Nicolas**, nasci em $São Paulo$. Não tenho *nenhuma* cor favorita. Ainda *NÃO* tenho certeza do que irei cursar, mas gosto muito de **Física**. $E = mc^2$

# %% [markdown]
# Meu nome é *Carlos Alencar*, nasci em *São Bernardo do Campo*, minha cor favorita é verde e eu pretendo cursar **ciência da programação** mas ainda não tenho certeza.

# %% [markdown]
# Meu nome é **Thayane**, nasci em Timóteo - Minas Gerais, minha cor favorita é o **roxo** e pretendo cursar *engenharia aeroespacial* ou *física* após o BCT.

# %% [markdown]
# Meu nome é **Arthur**, tenho 25 anos, nasci em *São Paulo* mas moro em *Itapecerica da Serra*. Minha cor favorita é verde e pretendo cursar $Engenharia Biomédica$.

# %% [markdown]
# Meu nome é **Caio Parra Fernandes**, tenho **18** anos, nasci em $São Paulo$, onde atualmente moro. Minha *$cor$* favorita é *azul*. Pretendo cursar ***Engenharia de Materiais*** após o término do **BCeT**.

# %% [markdown]
# Meu nome é **Thiago Braga de Almeida**, tenho $18$ anos, moro em *Arujá* mas nasci na cidade de *São Paulo*. Minha cor favorita é **branco**. Pretendo cursar ***Ciências da Computação***.

# %% [markdown]
# Meu nome é **Nathália**, nasci em *São Paulo, 2002*. Gosto de muitas cores e quero cursar ***Eng. Ambiental*** após BI.

# %% [markdown]
# Oi, meu nome é **Caroline** e eu tenho *19* anos. Moro em $São Bernardo do Campo$, mas meu campus fica em ~~Santo André~~  pois, *por incrível que pareça*, é mais fácil de chegar *(de ônibus, pelo menos)*.
#
# Meu cantor favorito é o $Shawn Mendes$ e meu doce favorito é ~~Talento de morango~~. $a^2=b^2+c^2$

# %% [markdown]
# Olá! Meu nome é $Amanda$, nasci em **São Paulo**. Tenho *18 anos*. Me interesso por áreas como robótica e sustentabilidade porém ainda não decidi meu pós-BI.

# %% [markdown]
# Oi, meu nome é $Liandra$, tenho *18 anos* e sou de *São Paulo*. Gosto de ***muitas cores***, mas o ***roxo*** e ***verde*** são as preferidas.
#
# ![1b06dd0596fd3966eb26dff693163fb0.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Meu nome é **Isabele**, tenho $18$ anos, moro em Santo André. Minha cor preferida é *verde-água*.

# %% [markdown]
# Meu nome é **Fernanda Alves**, tenho *20 anos*, nasci em **São Bernardo do Campo** mas meu campus é em **Santo André** onde eu pretendo cursar *Engenharia de Materiais*. Minha cor preferida é $verde-água$

# %% [markdown]
# ### Olá meu *nome* é **Gabriel Kuroki** tenho **23** anos, moro em ***São Paulo*** e minha cor preferida é ***azul escuro***.

# %% [markdown]
# Meu nome é **Danielle Carotta**, tenho *20 anos*, nasci em *São Paulo* mas vivo em **Santo André** e minha cor favorita é **preto.**

# %% [markdown]
# Meu nome é **Gustavo Silva Querichelli**, tenho *19 anos*, nasci e moro em **SP, Capital** e minhas cores preferidas são *preto e azul*.

# %% [markdown]
# Meu nome é **Thierry Garre**, tenho 20 anos, nasci e moro em *Santos*, minha cor preferida é Azul e vou cursar ***Ciência da Computação.***

# %% [markdown]
# Meu nome é **Luís**, tenho 19 anos e nasci em São Paulo. Minha cor preferida é $VERMELHO$ e quero cursar **Neurociencia**.

# %% [markdown]
# Meu nome é **Beatriz**, tenho 19 anos, nasci em *campinas*, minha cor preferida é Azul e quero cursar ***engenharia aeroespacial***

# %% [markdown]
# Meu nome é **Laura** tenho 17 anos, nasci em **São Paulo**. Quero cursar *Engenharia Aeroespacial*. Minha cor predileta é **azul** e meu esporte favorito é **vôlei**! Minha fórmula favorita é **F= m x a**

# %% [markdown]
# Meu nome é **Marco**, tenho 19 anos e sou de São Paulo. Minha cor favorita é #1fedac e quero cursar Ciência da Computação.
# > public static void main(String[] args){ System.out.println("Java é uma porcaria"); }

# %% [markdown]
# Meu nome é **Maria Beatriz**. *tenho 18 anos*, e pretendo estudar neurociência ou computação. A única fórmula que eu lembro: $S= So+v*t$

# %% [markdown]
# Meu nome é **Alicia**, tenho 20 anos e pretendo cursar **engenharia aeroespacial**, e ciência da computação ou neuro como segunda graduação. Minha fórmula favorita é *F=m.a* e minha cor favorita é preto.

# %%
x= np.linspace(0,5,100)
y= np.sin(4*x)*np.exp(-x)
z= np.exp(-x)*np.cos(4*x)
plt.figure(dpi=100, facecolor='m')
plt.plot(x,y,'m-.', label='$e^{-x}sin(4x)$', linewidth= 1.0)
plt.xlabel('eixo x')
plt.ylabel('eixo y')
plt.legend()
